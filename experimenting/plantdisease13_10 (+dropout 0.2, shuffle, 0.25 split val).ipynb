# %%
#########################
from google.colab import drive
drive.mount('/content/drive')
print('')

#########################
import numpy as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.python.keras.applications.resnet import ResNet50
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.python.keras import optimizers
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.applications.resnet50 import preprocess_input
from keras.preprocessing.image import ImageDataGenerator

#########################
data_dir = '/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train'

num_classes = 10
channels = 3
img_size = 224

resnet50_pooling = 'avg'
resnet50_weight = 'imagenet'
dense_layer_activation = 'softmax'
objective_function = 'categorical_crossentropy'
loss_metrics = ['accuracy']

learning_rate = 0.001
beta_1=0.9
beta_2=0.999

num_epochs = 50
early_stop_patience = 3
steps_per_epochs_training = 10
steps_per_epochs_validation = 10

batch_size_training = 50
batch_size_validation = 50
batch_size_testing = 1

#########################
model = Sequential()
model.add(ResNet50(include_top = False, pooling = resnet50_pooling, weights = resnet50_weight, input_shape=(img_size, img_size, channels)))
model.add(BatchNormalization())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(Dense(num_classes, activation = dense_layer_activation))

model.layers[0].trainable = False

adam = tf.keras.optimizers.Adam(lr=learning_rate, beta_1=beta_1, beta_2=beta_2)
model.compile(optimizer = adam, loss = objective_function, metrics = loss_metrics)

model.summary()
print('')

##########################
data_generator = ImageDataGenerator(preprocessing_function=preprocess_input, validation_split=0.25)

train_generator = data_generator.flow_from_directory(
        data_dir,
        target_size=(img_size, img_size),
        batch_size=batch_size_training,
        shuffle = True,
        class_mode='categorical')

validation_generator = data_generator.flow_from_directory(
    data_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size_validation,
    shuffle = True,
    class_mode='categorical',
    subset='validation')
print('')

##########################
fit_history = model.fit_generator(
        train_generator,
        steps_per_epoch=steps_per_epochs_training,
        epochs = num_epochs,
        validation_data = validation_generator,
        validation_steps = 1000//batch_size_validation
)
print('')

##########################
plt.figure(1, figsize = (15,8)) 
    
plt.subplot(221)  
plt.plot(fit_history.history['accuracy'])  
plt.plot(fit_history.history['val_accuracy'])  
plt.title('model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid']) 
    
plt.subplot(222)  
plt.plot(fit_history.history['loss'])  
plt.plot(fit_history.history['val_loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid']) 

plt.show()
# Out:
# Mounted at /content/drive
# Using TensorFlow backend.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 3s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 2048)              23587712
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2048)              8192
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 24,156,170
# Trainable params: 563,594
# Non-trainable params: 23,592,576
# _________________________________________________________________
#
# Found 5000 images belonging to 10 classes.
# Found 1250 images belonging to 10 classes.
#
# WARNING:tensorflow:From <ipython-input-1-73d758a91e6b>:89: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 10/10 [==============================] - 755s 76s/step - loss: 1.4205 - accuracy: 0.5340 - val_loss: 1.5197 - val_accuracy: 0.4150
# Epoch 2/50
# 10/10 [==============================] - 416s 42s/step - loss: 0.4420 - accuracy: 0.8800 - val_loss: 1.0225 - val_accuracy: 0.6890
# Epoch 3/50
# 10/10 [==============================] - 329s 33s/step - loss: 0.2835 - accuracy: 0.9180 - val_loss: 0.9314 - val_accuracy: 0.6900
# Epoch 4/50
# 10/10 [==============================] - 341s 34s/step - loss: 0.2669 - accuracy: 0.9280 - val_loss: 0.8452 - val_accuracy: 0.7300
# Epoch 5/50
# 10/10 [==============================] - 321s 32s/step - loss: 0.1902 - accuracy: 0.9380 - val_loss: 0.7073 - val_accuracy: 0.7770
# Epoch 6/50
# 10/10 [==============================] - 331s 33s/step - loss: 0.1934 - accuracy: 0.9360 - val_loss: 0.7235 - val_accuracy: 0.7620
# Epoch 7/50
# 10/10 [==============================] - 321s 32s/step - loss: 0.1696 - accuracy: 0.9440 - val_loss: 0.7473 - val_accuracy: 0.7410
# Epoch 8/50
# 10/10 [==============================] - 324s 32s/step - loss: 0.1492 - accuracy: 0.9580 - val_loss: 0.7563 - val_accuracy: 0.7380
# Epoch 9/50
# 10/10 [==============================] - 330s 33s/step - loss: 0.1067 - accuracy: 0.9680 - val_loss: 0.7166 - val_accuracy: 0.7410
# Epoch 10/50
# 10/10 [==============================] - 331s 33s/step - loss: 0.1546 - accuracy: 0.9440 - val_loss: 0.7466 - val_accuracy: 0.7370
# Epoch 11/50
# 10/10 [==============================] - 219s 22s/step - loss: 0.0784 - accuracy: 0.9800 - val_loss: 0.6392 - val_accuracy: 0.7800
# Epoch 12/50
# 10/10 [==============================] - 220s 22s/step - loss: 0.0931 - accuracy: 0.9720 - val_loss: 0.6707 - val_accuracy: 0.7710
# Epoch 13/50
# 10/10 [==============================] - 218s 22s/step - loss: 0.0827 - accuracy: 0.9840 - val_loss: 0.6986 - val_accuracy: 0.7410
# Epoch 14/50
# 10/10 [==============================] - 219s 22s/step - loss: 0.0670 - accuracy: 0.9880 - val_loss: 0.7887 - val_accuracy: 0.7070
# Epoch 15/50
# 10/10 [==============================] - 219s 22s/step - loss: 0.0644 - accuracy: 0.9880 - val_loss: 0.7658 - val_accuracy: 0.7130
# Epoch 16/50
# 10/10 [==============================] - 218s 22s/step - loss: 0.0824 - accuracy: 0.9760 - val_loss: 0.8072 - val_accuracy: 0.6930
# Epoch 17/50
# 10/10 [==============================] - 219s 22s/step - loss: 0.0756 - accuracy: 0.9820 - val_loss: 0.7989 - val_accuracy: 0.7250
# Epoch 18/50
# 10/10 [==============================] - 218s 22s/step - loss: 0.0472 - accuracy: 0.9900 - val_loss: 0.8950 - val_accuracy: 0.6800
# Epoch 19/50
# 10/10 [==============================] - 218s 22s/step - loss: 0.0572 - accuracy: 0.9900 - val_loss: 0.9211 - val_accuracy: 0.6580
# Epoch 20/50
# 10/10 [==============================] - 220s 22s/step - loss: 0.0862 - accuracy: 0.9820 - val_loss: 0.9945 - val_accuracy: 0.6460
# Epoch 21/50
# 10/10 [==============================] - 220s 22s/step - loss: 0.0443 - accuracy: 0.9880 - val_loss: 1.1358 - val_accuracy: 0.6010
# Epoch 22/50
# 10/10 [==============================] - 219s 22s/step - loss: 0.0433 - accuracy: 0.9920 - val_loss: 1.1568 - val_accuracy: 0.5820
# Epoch 23/50
# 10/10 [==============================] - 221s 22s/step - loss: 0.0398 - accuracy: 0.9960 - val_loss: 1.2272 - val_accuracy: 0.5900
# Epoch 24/50
# 10/10 [==============================] - 220s 22s/step - loss: 0.0334 - accuracy: 0.9920 - val_loss: 1.1791 - val_accuracy: 0.5880
# Epoch 25/50
# 10/10 [==============================] - 222s 22s/step - loss: 0.0364 - accuracy: 0.9880 - val_loss: 1.2877 - val_accuracy: 0.5620
# Epoch 26/50
# 10/10 [==============================] - 221s 22s/step - loss: 0.0462 - accuracy: 0.9860 - val_loss: 1.1319 - val_accuracy: 0.6080
# Epoch 27/50
# 10/10 [==============================] - 223s 22s/step - loss: 0.0423 - accuracy: 0.9880 - val_loss: 1.0540 - val_accuracy: 0.6470
# Epoch 28/50
# 10/10 [==============================] - 222s 22s/step - loss: 0.0289 - accuracy: 0.9940 - val_loss: 1.1271 - val_accuracy: 0.6210
# Epoch 29/50
# 10/10 [==============================] - 220s 22s/step - loss: 0.0354 - accuracy: 0.9940 - val_loss: 1.2590 - val_accuracy: 0.5960
# Epoch 30/50
# 10/10 [==============================] - 220s 22s/step - loss: 0.0370 - accuracy: 0.9900 - val_loss: 1.3245 - val_accuracy: 0.5800
# Epoch 31/50
# 10/10 [==============================] - 219s 22s/step - loss: 0.0244 - accuracy: 0.9960 - val_loss: 1.2015 - val_accuracy: 0.6010
# Epoch 32/50
# 10/10 [==============================] - 220s 22s/step - loss: 0.0435 - accuracy: 0.9900 - val_loss: 1.0871 - val_accuracy: 0.6320
# Epoch 33/50
# 10/10 [==============================] - 220s 22s/step - loss: 0.0296 - accuracy: 0.9940 - val_loss: 1.1074 - val_accuracy: 0.6520
# Epoch 34/50
# 10/10 [==============================] - 220s 22s/step - loss: 0.0232 - accuracy: 0.9960 - val_loss: 1.4219 - val_accuracy: 0.5780
# Epoch 35/50
# 10/10 [==============================] - 220s 22s/step - loss: 0.0381 - accuracy: 0.9820 - val_loss: 1.4906 - val_accuracy: 0.5560
# Epoch 36/50
# 10/10 [==============================] - 221s 22s/step - loss: 0.0377 - accuracy: 0.9880 - val_loss: 1.5636 - val_accuracy: 0.5540
# Epoch 37/50
# 10/10 [==============================] - 221s 22s/step - loss: 0.0329 - accuracy: 0.9960 - val_loss: 1.4581 - val_accuracy: 0.5690
# Epoch 38/50
# 10/10 [==============================] - 220s 22s/step - loss: 0.0307 - accuracy: 0.9940 - val_loss: 1.4781 - val_accuracy: 0.5880
# Epoch 39/50
# 10/10 [==============================] - 219s 22s/step - loss: 0.0263 - accuracy: 0.9940 - val_loss: 1.4798 - val_accuracy: 0.5840
# Epoch 40/50
# 10/10 [==============================] - 220s 22s/step - loss: 0.0296 - accuracy: 0.9920 - val_loss: 1.5349 - val_accuracy: 0.5920
# Epoch 41/50
# 10/10 [==============================] - 221s 22s/step - loss: 0.0349 - accuracy: 0.9940 - val_loss: 1.5740 - val_accuracy: 0.5950
# Epoch 42/50
# 10/10 [==============================] - 222s 22s/step - loss: 0.0295 - accuracy: 0.9900 - val_loss: 1.7144 - val_accuracy: 0.5580
# Epoch 43/50
# 10/10 [==============================] - 221s 22s/step - loss: 0.0243 - accuracy: 0.9900 - val_loss: 1.4938 - val_accuracy: 0.5830
# Epoch 44/50
# 10/10 [==============================] - 222s 22s/step - loss: 0.0268 - accuracy: 0.9960 - val_loss: 1.4728 - val_accuracy: 0.6120
# Epoch 45/50
# 10/10 [==============================] - 220s 22s/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 1.3876 - val_accuracy: 0.6370
# Epoch 46/50
# 10/10 [==============================] - 221s 22s/step - loss: 0.0270 - accuracy: 0.9900 - val_loss: 1.4489 - val_accuracy: 0.5930
# Epoch 47/50
# 10/10 [==============================] - 221s 22s/step - loss: 0.0224 - accuracy: 0.9960 - val_loss: 1.4385 - val_accuracy: 0.6260
# Epoch 48/50
# 10/10 [==============================] - 221s 22s/step - loss: 0.0320 - accuracy: 0.9920 - val_loss: 1.9299 - val_accuracy: 0.5480
# Epoch 49/50
# 10/10 [==============================] - 219s 22s/step - loss: 0.0314 - accuracy: 0.9880 - val_loss: 2.0721 - val_accuracy: 0.5420
# Epoch 50/50
# 10/10 [==============================] - 222s 22s/step - loss: 0.0313 - accuracy: 0.9900 - val_loss: 1.7900 - val_accuracy: 0.5700

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
print('train apple (healthy) images:', len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Apple___healthy')))
print('train apple (apple scab) images:', len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Apple___Apple_scab')))
print('train apple (black rot) images:', len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Apple___Black_rot')))
print('train apple (cedar apple rust) images:', len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Apple___Cedar_apple_rust')))
train_total_apple = len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Apple___healthy')) + len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Apple___Apple_scab')) + len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Apple___Black_rot')) + len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Apple___Cedar_apple_rust'))
print('total apple images:', train_total_apple)
print()
print('train grape (healthy) images:', len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Grape___healthy')))
print('train grape (esca) images:', len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Grape___Esca_(Black_Measles)')))
print('train grape (black rot) images:', len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Grape___Black_rot')))
print('train grape (leaf blight) images:', len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Grape___Leaf_blight_(Isariopsis_Leaf_Spot)')))
train_total_grape = len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Grape___healthy')) + len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Grape___Esca_(Black_Measles)')) + len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Grape___Black_rot')) + len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Grape___Leaf_blight_(Isariopsis_Leaf_Spot)'))
print('total grape images:', train_total_grape)
print()
print('train potato (healthy) images:', len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Potato___healthy')))
print('train potato (early blight) images:', len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Potato___Early_blight')))
print('train potato (late blight) images:', len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Potato___Late_blight')))
train_total_potato = len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Potato___healthy')) + len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Potato___Early_blight')) + len(os.listdir('/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train/Potato___Late_blight'))
print('total potato images:', train_total_potato)
print()
print('total train images:', train_total_apple + train_total_grape + train_total_potato)
# Out:
# train apple (healthy) images: 1316
# train apple (apple scab) images: 504
# train apple (black rot) images: 497
# train apple (cedar apple rust) images: 220
# total apple images: 2537
#
# train grape (healthy) images: 339
# train grape (esca) images: 1107
# train grape (black rot) images: 944
# train grape (leaf blight) images: 861
# total grape images: 3251
#
# train potato (healthy) images: 122
# train potato (early blight) images: 800
# train potato (late blight) images: 800
# total potato images: 1722
#
# total train images: 7510

# %%
#apple
# Parameter 4x5 configuration
nrows = 4
ncols = 5
 
# Index for iterating over images
pic_index = 0

# Set up matplotlib fig, and size it to fit 4x5 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 2, nrows * 2)
 
pic_index += 5
next_apple_healthy_pix = [os.path.join(train_apple_healthy_dir, fname) 
                for fname in train_apple_healthy_names[pic_index-5:pic_index]]
next_apple_scab_pix = [os.path.join(train_apple_scab_dir, fname) 
                for fname in train_apple_scab_names[pic_index-5:pic_index]]
next_apple_blackrot_pix = [os.path.join(train_apple_blackrot_dir, fname)
                for fname in train_apple_blackrot_names[pic_index-5:pic_index]]
next_apple_cedarrust_pix = [os.path.join(train_apple_cedarrust_dir, fname)
                for fname in train_apple_cedarrust_names[pic_index-5:pic_index]]
 
for i, img_path in enumerate(next_apple_healthy_pix + next_apple_scab_pix + next_apple_blackrot_pix + next_apple_cedarrust_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)
 
  img = mpimg.imread(img_path)
  plt.imshow(img)

print('Apple: Healthy, Scab, Black rot, Cedar rust')
plt.show()

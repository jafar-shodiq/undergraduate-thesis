# %%
#########################
from google.colab import drive
drive.mount('/content/drive')
print('')

#########################
import numpy as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.python.keras.applications.resnet import ResNet50
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.python.keras import optimizers
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.applications.resnet50 import preprocess_input
from keras.preprocessing.image import ImageDataGenerator

#########################
data_dir = '/content/drive/My Drive/Dataset/plantdisease-tugasakhir/train'

num_classes = 10
channels = 3
img_size = 224

resnet50_pooling = 'avg'
resnet50_weight = 'imagenet'
dense_layer_activation = 'softmax'
objective_function = 'categorical_crossentropy'
loss_metrics = ['accuracy']

learning_rate = 0.001
beta_1=0.9
beta_2=0.999

num_epochs = 50
early_stop_patience = 3
steps_per_epochs_training = 10
steps_per_epochs_validation = 10

batch_size_training = 50
batch_size_validation = 50
batch_size_testing = 1

#########################
model = Sequential()
model.add(ResNet50(include_top = False, pooling = resnet50_pooling, weights = resnet50_weight, input_shape=(img_size, img_size, channels)))
model.add(BatchNormalization())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(num_classes, activation = dense_layer_activation))

model.layers[0].trainable = False

adam = tf.keras.optimizers.Adam(lr=learning_rate, beta_1=beta_1, beta_2=beta_2)
model.compile(optimizer = adam, loss = objective_function, metrics = loss_metrics)

model.summary()
print('')

##########################
data_generator = ImageDataGenerator(preprocessing_function=preprocess_input, validation_split=0.2)

train_generator = data_generator.flow_from_directory(
        data_dir,
        target_size=(img_size, img_size),
        batch_size=batch_size_training,
        class_mode='categorical')

validation_generator = data_generator.flow_from_directory(
    data_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size_validation,
    class_mode='categorical',
    subset='validation')
print('')

##########################
fit_history = model.fit_generator(
        train_generator,
        steps_per_epoch=steps_per_epochs_training,
        epochs = num_epochs,
        validation_data = validation_generator,
        validation_steps = 1000//batch_size_validation
)
print('')

##########################
plt.figure(1, figsize = (15,8)) 
    
plt.subplot(221)  
plt.plot(fit_history.history['accuracy'])  
plt.plot(fit_history.history['val_accuracy'])  
plt.title('model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid']) 
    
plt.subplot(222)  
plt.plot(fit_history.history['loss'])  
plt.plot(fit_history.history['val_loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid']) 

plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 2048)              23587712
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 2048)              8192
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               524544
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128)               512
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 24,156,170
# Trainable params: 563,594
# Non-trainable params: 23,592,576
# _________________________________________________________________
#
# Found 5000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.
#
# Epoch 1/50
# 10/10 [==============================] - 7s 744ms/step - loss: 1.0775 - accuracy: 0.6480 - val_loss: 1.3434 - val_accuracy: 0.6100
# Epoch 2/50
# 10/10 [==============================] - 7s 665ms/step - loss: 0.2907 - accuracy: 0.9060 - val_loss: 1.0090 - val_accuracy: 0.6700
# Epoch 3/50
# 10/10 [==============================] - 7s 661ms/step - loss: 0.1924 - accuracy: 0.9460 - val_loss: 0.9476 - val_accuracy: 0.6500
# Epoch 4/50
# 10/10 [==============================] - 7s 665ms/step - loss: 0.1516 - accuracy: 0.9540 - val_loss: 1.0229 - val_accuracy: 0.5850
# Epoch 5/50
# 10/10 [==============================] - 7s 664ms/step - loss: 0.1236 - accuracy: 0.9580 - val_loss: 1.2319 - val_accuracy: 0.5060
# Epoch 6/50
# 10/10 [==============================] - 7s 669ms/step - loss: 0.1309 - accuracy: 0.9580 - val_loss: 1.3009 - val_accuracy: 0.5080
# Epoch 7/50
# 10/10 [==============================] - 7s 665ms/step - loss: 0.1263 - accuracy: 0.9560 - val_loss: 1.3198 - val_accuracy: 0.5170
# Epoch 8/50
# 10/10 [==============================] - 7s 668ms/step - loss: 0.1043 - accuracy: 0.9620 - val_loss: 1.1680 - val_accuracy: 0.5530
# Epoch 9/50
# 10/10 [==============================] - 7s 667ms/step - loss: 0.1297 - accuracy: 0.9560 - val_loss: 1.2412 - val_accuracy: 0.5250
# Epoch 10/50
# 10/10 [==============================] - 7s 667ms/step - loss: 0.1096 - accuracy: 0.9640 - val_loss: 1.4703 - val_accuracy: 0.4650
# Epoch 11/50
# 10/10 [==============================] - 7s 668ms/step - loss: 0.0371 - accuracy: 0.9920 - val_loss: 1.3321 - val_accuracy: 0.4730
# Epoch 12/50
# 10/10 [==============================] - 7s 671ms/step - loss: 0.0562 - accuracy: 0.9880 - val_loss: 1.3923 - val_accuracy: 0.4750
# Epoch 13/50
# 10/10 [==============================] - 7s 671ms/step - loss: 0.0462 - accuracy: 0.9920 - val_loss: 1.2493 - val_accuracy: 0.5060
# Epoch 14/50
# 10/10 [==============================] - 7s 670ms/step - loss: 0.0329 - accuracy: 0.9960 - val_loss: 1.3711 - val_accuracy: 0.4880
# Epoch 15/50
# 10/10 [==============================] - 7s 671ms/step - loss: 0.0290 - accuracy: 0.9960 - val_loss: 1.2950 - val_accuracy: 0.5190
# Epoch 16/50
# 10/10 [==============================] - 7s 667ms/step - loss: 0.0314 - accuracy: 0.9920 - val_loss: 1.2627 - val_accuracy: 0.5270
# Epoch 17/50
# 10/10 [==============================] - 7s 668ms/step - loss: 0.0340 - accuracy: 0.9900 - val_loss: 1.3233 - val_accuracy: 0.5370
# Epoch 18/50
# 10/10 [==============================] - 7s 670ms/step - loss: 0.0322 - accuracy: 0.9940 - val_loss: 1.3025 - val_accuracy: 0.5410
# Epoch 19/50
# 10/10 [==============================] - 7s 668ms/step - loss: 0.0284 - accuracy: 0.9920 - val_loss: 1.3765 - val_accuracy: 0.5230
# Epoch 20/50
# 10/10 [==============================] - 7s 671ms/step - loss: 0.0194 - accuracy: 0.9960 - val_loss: 1.5248 - val_accuracy: 0.4780
# Epoch 21/50
# 10/10 [==============================] - 7s 679ms/step - loss: 0.0167 - accuracy: 0.9980 - val_loss: 1.6614 - val_accuracy: 0.4620
# Epoch 22/50
# 10/10 [==============================] - 7s 675ms/step - loss: 0.0221 - accuracy: 0.9960 - val_loss: 1.8850 - val_accuracy: 0.4270
# Epoch 23/50
# 10/10 [==============================] - 7s 668ms/step - loss: 0.0152 - accuracy: 0.9980 - val_loss: 1.9558 - val_accuracy: 0.4140
# Epoch 24/50
# 10/10 [==============================] - 7s 677ms/step - loss: 0.0181 - accuracy: 0.9960 - val_loss: 2.2592 - val_accuracy: 0.3950
# Epoch 25/50
# 10/10 [==============================] - 7s 671ms/step - loss: 0.0289 - accuracy: 0.9940 - val_loss: 1.9813 - val_accuracy: 0.4330
# Epoch 26/50
# 10/10 [==============================] - 7s 670ms/step - loss: 0.0216 - accuracy: 0.9920 - val_loss: 2.2719 - val_accuracy: 0.4010
# Epoch 27/50
# 10/10 [==============================] - 7s 670ms/step - loss: 0.0156 - accuracy: 0.9980 - val_loss: 2.3949 - val_accuracy: 0.4130
# Epoch 28/50
# 10/10 [==============================] - 7s 670ms/step - loss: 0.0174 - accuracy: 0.9960 - val_loss: 2.4714 - val_accuracy: 0.4050
# Epoch 29/50
# 10/10 [==============================] - 7s 669ms/step - loss: 0.0161 - accuracy: 0.9960 - val_loss: 2.6125 - val_accuracy: 0.4110
# Epoch 30/50
# 10/10 [==============================] - 7s 672ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 2.7403 - val_accuracy: 0.3820
# Epoch 31/50
# 10/10 [==============================] - 7s 672ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 3.1360 - val_accuracy: 0.3650
# Epoch 32/50
# 10/10 [==============================] - 7s 670ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 3.3020 - val_accuracy: 0.3440
# Epoch 33/50
# 10/10 [==============================] - 7s 678ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 3.4578 - val_accuracy: 0.3370
# Epoch 34/50
# 10/10 [==============================] - 7s 673ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 2.9845 - val_accuracy: 0.3680
# Epoch 35/50
# 10/10 [==============================] - 7s 670ms/step - loss: 0.0181 - accuracy: 0.9940 - val_loss: 2.6495 - val_accuracy: 0.3840
# Epoch 36/50
# 10/10 [==============================] - 7s 668ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 2.1132 - val_accuracy: 0.4290
# Epoch 37/50
# 10/10 [==============================] - 7s 672ms/step - loss: 0.0117 - accuracy: 0.9980 - val_loss: 2.0812 - val_accuracy: 0.4590
# Epoch 38/50
# 10/10 [==============================] - 7s 668ms/step - loss: 0.0095 - accuracy: 0.9980 - val_loss: 2.1757 - val_accuracy: 0.4480
# Epoch 39/50
# 10/10 [==============================] - 7s 669ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 2.2657 - val_accuracy: 0.4340
# Epoch 40/50
# 10/10 [==============================] - 7s 668ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 2.3892 - val_accuracy: 0.4230
# Epoch 41/50
# 10/10 [==============================] - 7s 670ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 2.4006 - val_accuracy: 0.4340
# Epoch 42/50
# 10/10 [==============================] - 7s 669ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 2.4184 - val_accuracy: 0.4390
# Epoch 43/50
# 10/10 [==============================] - 7s 672ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 2.3864 - val_accuracy: 0.4370
# Epoch 44/50
# 10/10 [==============================] - 7s 670ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 2.3217 - val_accuracy: 0.4480
# Epoch 45/50
# 10/10 [==============================] - 7s 669ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 2.2283 - val_accuracy: 0.4680
# Epoch 46/50
# 10/10 [==============================] - 7s 671ms/step - loss: 0.0069 - accuracy: 0.9980 - val_loss: 2.1643 - val_accuracy: 0.4770
# Epoch 47/50
# 10/10 [==============================] - 7s 676ms/step - loss: 0.0074 - accuracy: 0.9980 - val_loss: 1.8659 - val_accuracy: 0.5250
# Epoch 48/50
# 10/10 [==============================] - 7s 666ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.8083 - val_accuracy: 0.5210
# Epoch 49/50
# 10/10 [==============================] - 7s 669ms/step - loss: 0.0087 - accuracy: 0.9980 - val_loss: 2.1268 - val_accuracy: 0.5010
# Epoch 50/50
# 10/10 [==============================] - 7s 670ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 2.5506 - val_accuracy: 0.4580

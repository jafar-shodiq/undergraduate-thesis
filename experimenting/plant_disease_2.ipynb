# %% [markdown]
# # TUGAS AKHIR

# %% [markdown]
# # Prepare Kaggle and Download Datasets

# %%
# !pip install kaggle

# %%
# !mkdir ~/.kaggle
# !mkdir .kaggle

# %%
# !ls -a
# Out:
# .  ..  .config	.kaggle  sample_data

# %%
import json
token = {"username":"jafarshodiq","key":"6dd1204b0c26f555c9de51f6d956a8b6"}
with open('/content/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)

# %%
# !chmod 600 /content/.kaggle/kaggle.json

# %%
# !cp /content/.kaggle/kaggle.json /root/.kaggle/kaggle.json

# %%
# !kaggle config set -n path -v{/content}
# Out:
# - path is now set to: {/content}

# %%
# !kaggle datasets download -d saroz014/plant-disease -p /content
# Out:
# ...
#  99% 1.59G/1.60G [00:21<00:00, 90.0MB/s]
# 100% 1.60G/1.60G [00:22<00:00, 77.9MB/s]

# %%
# !unzip \plant-disease.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/train/Tomato___Tomato_Yellow_Leaf_Curl_Virus/43a32428-0d45-4851-bb62-c1a669854990___YLCV_NREC 2630.JPG
#   inflating: dataset/train/Tomato___Tomato_Yellow_Leaf_Curl_Virus/43a5145b-57e9-4605-8ba3-1fb90f61d460___YLCV_NREC 0108.JPG
#   inflating: dataset/train/Tomato___Tomato_Yellow_Leaf_Curl_Virus/43a73727-237f-40e0-b7e1-95bf4d0eb756___YLCV_GCREC 5343.JPG
#   inflating: dataset/train/Tomato___Tomato_Yellow_Leaf_Curl_Virus/43aae6d1-40ae-42f4-8b71-ae9351683a90___UF.GRC_YLCV_Lab 02661.JPG
#   inflating: dataset/train/Tomato___Tomato_Yellow_Leaf_Curl_Virus/43b2be62-cb86-46f4-9049-92e77d4f335b___YLCV_NREC 0074.JPG
#   inflating: dataset/train/Tomato___Tomato_Yellow_Leaf_Curl_Virus/43b8aec7-59df-413d-9afd-9cbf481695fd___UF.GRC_YLCV_Lab 09423.JPG
#   inflating: dataset/train/Tomato___Tomato_Yellow_Leaf_Curl_Virus/43bbb298-8079-42f6-9be7-b88957cc8846___UF.GRC_YLCV_Lab 09341.JPG
# ...

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Train

# %%
import os
#apple 
train_apple_healthy_dir = os.path.join('/content/dataset/train/Apple___healthy/')
train_apple_scab_dir = os.path.join('/content/dataset/train/Apple___Apple_scab/')
train_apple_blackrot_dir = os.path.join('/content/dataset/train/Apple___Black_rot/')
train_apple_cedarrust_dir = os.path.join('/content/dataset/train/Apple___Cedar_apple_rust/')

#grape
train_grape_healthy_dir = os.path.join('/content/dataset/train/Grape___healthy/')
train_grape_esca_dir = os.path.join('/content/dataset/train/Grape___Esca_(Black_Measles)/')
train_grape_blackrot_dir = os.path.join('/content/dataset/train/Grape___Black_rot/')
train_grape_leafblight_dir = os.path.join('/content/dataset/train/Grape___Leaf_blight_(Isariopsis_Leaf_Spot)/')

#potato
train_potato_healthy_dir = os.path.join('/content/dataset/train/Potato___healthy/')
train_potato_earlyblight_dir = os.path.join('/content/dataset/train/Potato___Early_blight/')
train_potato_lateblight_dir = os.path.join('/content/dataset/train/Potato___Late_blight/')

# %%
#apple
train_apple_healthy_names = os.listdir(train_apple_healthy_dir)
train_apple_scab_names = os.listdir(train_apple_scab_dir)
train_apple_blackrot_names = os.listdir(train_apple_blackrot_dir)
train_apple_cedarrust_names = os.listdir(train_apple_cedarrust_dir)
print('apple:')
print(train_apple_healthy_names[:5])
print(train_apple_scab_names[:5])
print(train_apple_blackrot_names[:5])
print(train_apple_cedarrust_names[:5])

#grape
train_grape_healthy_names = os.listdir(train_grape_healthy_dir)
train_grape_esca_names = os.listdir(train_grape_esca_dir)
train_grape_blackrot_names = os.listdir(train_grape_blackrot_dir)
train_grape_leafblight_names = os.listdir(train_grape_leafblight_dir)
print('grape:')
print(train_grape_healthy_names[:5])
print(train_grape_esca_names[:5])
print(train_grape_blackrot_names[:5])
print(train_grape_leafblight_names[:5])

#potato
train_potato_healthy_names = os. listdir(train_potato_healthy_dir)
train_potato_earlyblight_names = os.listdir(train_potato_earlyblight_dir)
train_potato_lateblight_names = os.listdir(train_potato_lateblight_dir)
print('potato:')
print(train_potato_healthy_names[:5])
print(train_potato_earlyblight_names[:5])
print(train_potato_lateblight_names[:5])
# Out:
# apple:
# ['def9ef11-75da-4f8f-8334-c6c54a31d3d6___RS_HL 5936.JPG', '6695f23d-03f2-48ce-a3fe-b0fcd4f4972c___RS_HL 5884.JPG', '404ef08f-0f34-4530-bc4b-ce356b3c2da1___RS_HL 7484.JPG', 'f0cc8fe8-a9ec-42bb-83b7-274f8f5f00f0___RS_HL 7940.JPG', 'd87f5af4-6d78-40a7-838c-c5016a07a111___RS_HL 5676.JPG']
# ['14c623e5-051c-42f6-9e4f-f7a93e6a723c___FREC_Scab 2965.JPG', '61643f40-eb9a-4c6b-8de5-c12319fc7680___FREC_Scab 3114.JPG', 'fc9c12dc-1bdb-402d-ada8-dc1b33c84d5b___FREC_Scab 2932.JPG', '7897b5dc-7aa6-48b2-8c18-a30fcd6cae94___FREC_Scab 3203.JPG', '075b1885-250b-4b3e-8168-e54efdbb04e8___FREC_Scab 3173.JPG']
# ['337ea111-17e2-470d-8fae-1fe8c61c13dc___JR_FrgE.S 2985.JPG', 'f77c7ac1-f55e-4adc-b049-35def4e87c17___JR_FrgE.S 3077.JPG', '7f1f4f8b-86cc-4cc5-bb70-8b1653cea8ae___JR_FrgE.S 8649.JPG', 'fef17b16-ce22-4cb6-ba6a-270f5e08a17d___JR_FrgE.S 2843.JPG', '28f01d7f-27f8-4cf1-a473-ef4744b2dc61___JR_FrgE.S 8597.JPG']
# ...

# %%
print('train apple (healthy) images:', len(os.listdir(train_apple_healthy_dir)))
print('train apple (apple scab) images:', len(os.listdir(train_apple_scab_dir)))
print('train apple (black rot) images:', len(os.listdir(train_apple_blackrot_dir)))
print('train apple (cedar apple rust) images:', len(os.listdir(train_apple_cedarrust_dir)))
train_total_apple = len(os.listdir(train_apple_healthy_dir)) + len(os.listdir(train_apple_scab_dir)) + len(os.listdir(train_apple_blackrot_dir)) + len(os.listdir(train_apple_cedarrust_dir))
print('total apple images:', train_total_apple)
print()
print('train grape (healthy) images:', len(os.listdir(train_grape_healthy_dir)))
print('train grape (esca) images:', len(os.listdir(train_grape_esca_dir)))
print('train grape (black rot) images:', len(os.listdir(train_grape_blackrot_dir)))
print('train grape (leaf blight) images:', len(os.listdir(train_grape_leafblight_dir)))
train_total_grape = len(os.listdir(train_grape_healthy_dir)) + len(os.listdir(train_grape_esca_dir)) + len(os.listdir(train_grape_blackrot_dir)) + len(os.listdir(train_grape_leafblight_dir))
print('total grape images:', train_total_grape)
print()
print('train potato (healthy) images:', len(os.listdir(train_potato_healthy_dir)))
print('train potato (early blight) images:', len(os.listdir(train_potato_earlyblight_dir)))
print('train potato (late blight) images:', len(os.listdir(train_potato_lateblight_dir)))
train_total_potato = len(os.listdir(train_potato_healthy_dir)) + len(os.listdir(train_potato_earlyblight_dir)) + len(os.listdir(train_potato_lateblight_dir))
print('total potato images:', train_total_potato)
print()
print('total train images:', train_total_apple + train_total_grape + train_total_potato)
# Out:
# train apple (healthy) images: 1316
# train apple (apple scab) images: 504
# train apple (black rot) images: 497
# train apple (cedar apple rust) images: 220
# total apple images: 2537
#
# train grape (healthy) images: 339
# train grape (esca) images: 1107
# train grape (black rot) images: 944
# train grape (leaf blight) images: 861
# total grape images: 3251
#
# train potato (healthy) images: 122
# train potato (early blight) images: 800
# train potato (late blight) images: 800
# total potato images: 1722
#
# total train images: 7510

# %%
os.makedirs('data/train/Apple___healthy')
os.makedirs('data/train/Apple___Apple_scab')
os.makedirs('data/train/Apple___Black_rot')
os.makedirs('data/train/Apple___Cedar_apple_rust')

os.makedirs('data/train/Grape___healthy')
os.makedirs('data/train/Grape___Esca_(Black_Measles)')
os.makedirs('data/train/Grape___Black_rot')
os.makedirs('data/train/Grape___Leaf_blight_(Isariopsis_Leaf_Spot)')

os.makedirs('data/train/Potato___healthy')
os.makedirs('data/train/Potato___Early_blight')
os.makedirs('data/train/Potato___Late_blight')

# %%
import shutil
#apple
for f in train_apple_healthy_names:
  shutil.copy(train_apple_healthy_dir+f, 'data/train/Apple___healthy')
for f in train_apple_scab_names:
  shutil.copy(train_apple_scab_dir+f,  'data/train/Apple___Apple_scab')
for f in train_apple_blackrot_names:
  shutil.copy(train_apple_blackrot_dir+f, 'data/train/Apple___Black_rot')
for f in train_apple_cedarrust_names:
  shutil.copy(train_apple_cedarrust_dir+f, 'data/train/Apple__Cedar_apple_rust')

#grape
for f in train_grape_healthy_names:
  shutil.copy(train_grape_healthy_dir+f, 'data/train/Grape___healthy')
for f in train_grape_esca_names:
  shutil.copy(train_grape_esca_dir+f, 'data/train/Grape___Esca_(Black_Measles)')
for f in train_grape_blackrot_names:
  shutil.copy(train_grape_blackrot_dir+f, 'data/train/Grape___Black_rot')
for f in train_grape_leafblight_names:
  shutil.copy(train_grape_leafblight_dir+f, 'data/train/Grape___Leaf_blight_(Isariopsis_Leaf_Spot)')

#potato
for f in train_potato_healthy_names:
  shutil.copy(train_potato_healthy_dir+f, 'data/train/Potato___healthy')
for f in train_potato_earlyblight_names:
  shutil.copy(train_potato_earlyblight_dir+f, 'data/train/Potato___Early_blight')
for f in train_potato_lateblight_names:
  shutil.copy(train_potato_lateblight_dir+f, 'data/train/Potato___Late_blight')

# %%
train_dir = os.path.join('data/train')

# %%
# %matplotlib inline
 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
#apple
# Parameter 4x5 configuration
nrows = 4
ncols = 5
 
# Index for iterating over images
pic_index = 0

# Set up matplotlib fig, and size it to fit 4x5 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 2, nrows * 2)
 
pic_index += 5
next_apple_healthy_pix = [os.path.join(train_apple_healthy_dir, fname) 
                for fname in train_apple_healthy_names[pic_index-5:pic_index]]
next_apple_scab_pix = [os.path.join(train_apple_scab_dir, fname) 
                for fname in train_apple_scab_names[pic_index-5:pic_index]]
next_apple_blackrot_pix = [os.path.join(train_apple_blackrot_dir, fname)
                for fname in train_apple_blackrot_names[pic_index-5:pic_index]]
next_apple_cedarrust_pix = [os.path.join(train_apple_cedarrust_dir, fname)
                for fname in train_apple_cedarrust_names[pic_index-5:pic_index]]
 
for i, img_path in enumerate(next_apple_healthy_pix + next_apple_scab_pix + next_apple_blackrot_pix + next_apple_cedarrust_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)
 
  img = mpimg.imread(img_path)
  plt.imshow(img)

print('Apple: Healthy, Scab, Black rot, Cedar rust')
plt.show()
# Out:
# Apple: Healthy, Scab, Black rot, Cedar rust

# %%
#grape
# Parameter 4x5 configuration
nrows = 4
ncols = 5
 
# Index for iterating over images
pic_index = 0

# Set up matplotlib fig, and size it to fit 4x5 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 2, nrows * 2)
 
pic_index += 5
next_grape_healthy_pix = [os.path.join(train_grape_healthy_dir, fname) 
                for fname in train_grape_healthy_names[pic_index-5:pic_index]]
next_grape_esca_pix = [os.path.join(train_grape_esca_dir, fname) 
                for fname in train_grape_esca_names[pic_index-5:pic_index]]
next_grape_blackrot_pix = [os.path.join(train_grape_blackrot_dir, fname)
                for fname in train_grape_blackrot_names[pic_index-5:pic_index]]
next_grape_leafblight_pix = [os.path.join(train_grape_leafblight_dir, fname)
                for fname in train_grape_leafblight_names[pic_index-5:pic_index]]
 
for i, img_path in enumerate(next_grape_healthy_pix + next_grape_esca_pix + next_grape_blackrot_pix + next_grape_leafblight_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)
 
  img = mpimg.imread(img_path)
  plt.imshow(img)

print('Grape: Healthy, Esca (Black Measles), Black rot, Leaf blight')
plt.show()
# Out:
# Grape: Healthy, Esca (Black Measles), Black rot, Leaf blight

# %%
#potato
# Parameter 4x5 configuration
nrows = 3
ncols = 5
 
# Index for iterating over images
pic_index = 0

# Set up matplotlib fig, and size it to fit 4x5 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 2, nrows * 2)
 
pic_index += 5
next_potato_healthy_pix = [os.path.join(train_potato_healthy_dir, fname) 
                for fname in train_potato_healthy_names[pic_index-5:pic_index]]
next_potato_earlyblight_pix = [os.path.join(train_potato_earlyblight_dir, fname) 
                for fname in train_potato_earlyblight_names[pic_index-5:pic_index]]
next_potato_lateblight_pix = [os.path.join(train_potato_lateblight_dir, fname)
                for fname in train_potato_lateblight_names[pic_index-5:pic_index]]
 
for i, img_path in enumerate(next_potato_healthy_pix + next_potato_earlyblight_pix + next_potato_lateblight_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)
 
  img = mpimg.imread(img_path)
  plt.imshow(img)

print('Potato: Healthy, Early blight, Late blight')
plt.show()
# Out:
# Potato: Healthy, Early blight, Late blight

# %%
#data test, val

# %% [markdown]
# # Training Data

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense,MaxPooling2D,AveragePooling2D
from keras.preprocessing import image
from keras.applications.mobilenet import preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model, Input, load_model
from keras.optimizers import Adam,SGD,Adagrad,RMSprop 
from keras.utils import to_categorical
from tensorflow.keras.callbacks import TensorBoard
# %load_ext tensorboard
# Out:
# TensorFlow 2.x selected.
# Using TensorFlow backend.

# %%
print(tf.__version__)
# Out:
# 2.1.0

# %%
# !kaggle datasets download -d keras/resnet50 -p /content
# Out:
# ...
#  96% 168M/174M [00:02<00:00, 69.8MB/s]
# 100% 174M/174M [00:02<00:00, 83.4MB/s]

# %%
# !unzip \resnet50.zip
# Out:
# Archive:  resnet50.zip
#   inflating: imagenet_class_index.json
#   inflating: resnet50_weights_tf_dim_ordering_tf_kernels.h5
#   inflating: resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5

# %%
import os
os.makedirs('model/ResNet-50')

# %%
from keras.applications import ResNet50
weights_resnet50 = '/content/resnet50_weights_tf_dim_ordering_tf_kernels.h5'
weights_resnet50_notop = '/content/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5'

resnet_model = tf.keras.applications.ResNet50(weights=weights_resnet50_notop, input_shape = (256,256,3), include_top=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-64113c08fbc5> in <module>()
#       3 weights_resnet50_notop = '/content/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5'
#       4
# ----> 5 resnet_model = tf.keras.applications.ResNet50(weights=weights_resnet50_notop, input_shape = (256,256,3), include_top=True)
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/applications/__init__.py in wrapper(*args, **kwargs)
#      44     kwargs['models'] = models
#      45     kwargs['utils'] = all_utils
# ---> 46     return base_fun(*args, **kwargs)
#      47   return wrapper
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/applications/resnet.py in ResNet50(*args, **kwargs)
#      31 @keras_modules_injection
#      32 def ResNet50(*args, **kwargs):
# ---> 33   return resnet.ResNet50(*args, **kwargs)
#      34
#      35
#
# ...
